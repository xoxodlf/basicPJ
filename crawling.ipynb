# %%
import requests
from bs4 import BeautifulSoup

# %%
req = requests.get('https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%9D%B8%ED%84%B0%EB%84%B7_%EC%8B%A0%EC%A1%B0%EC%96%B4_%EB%AA%A9%EB%A1%9D')

# %%
html = req.text

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
html
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="ko" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>대한민국의 인터넷 신조어 목록 - 위키백과, 우리 모두의 백과사전</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"대한민국의_인터넷_신조어_목록","wgTitle":"대한민국의 인터넷 신조어 목록","wgCurRevisionId":23802109,"wgRevisionId":23802109,"wgArticleId":401519,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["깨진 링크를 가지고 있는 문서","독자 연구 의심 문서/2015년 12월","모든 독자 연구 의심 문서","독자 연구 의심 문서 - 전체","출처가 필요한 글/2017년 1월","출처가 필요한 모든 글","전체에 출처가 필요한 글","일본어 표기를 포함한 문서","영어 표기를 포함한 문서","인터넷 신조어","대한민국의 인터넷","대한민국의 신조어"],"wgBreakFrames":false,"wgPageContentLanguage":"ko","wgPageContentModel":"wikitext","wgSeparatorTransform
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>대한민국의 인터넷 신조어 목록 - 위키백과, 우리 모두의 백과사전</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
#mw-content-text > div > ul:nth-child(7) > li:nth-child(3) > b > a
words = soup.select(
    '#mw-content-text > div > ul > li > b'
    )

# %%
for word in words:
    print(word.text)
# Out:
# -각
# 가드올
# 가즈아
# 갓-
# 개-
# 검은머리 외국인
# 고고씽
# 고인물:
# 개인전(갠전)
# 개인톡(갠톡)
# 관심병
# 귀요미
# 귀차니즘
# 귀차니스트
# 그린라이트
# 급식충
# 기레기
# 김여사
# -까
# 꿀잼
# 끝판왕
# 낫닝겐
# 낚시
# 냥집사
# 네가지
# 노답
# 노잼
# 뇌피셜
# 눈팅
# 뉴비
# 늅늅
# 느금마
# 느개비/느그빠
# -느님
# 누물보
# 네다씹/ㄴㄷㅆ/ㄴㄷ^^
# ~다능
# 덕통사고
# 돋다
# 딸바보
# 떡실신
# 똥꼬충
# 동의?어보감
# 뒷담화
# 뚝배기
# ~당
# 링딩돋다
# 리즈시절
# 마초맨
# 머글
# 먹튀
# 멍 때리다
# 메퇘지
# 몸짱
# 몸짱
# 얼짱
# 므흣하다
# -밍아웃
# 반품남
# 반품녀
# 품절남
# 품절녀
# 방가요/방가방가
# 배사
# 번개팅
# 볍신
# 보슬아치
# 보이루
# 복돌이
# -부심
# 불곰국
# 뷁
# 뷁어
# 뷔페미니즘
# 벅세권
# -빠
# 빡돌다
# 빡세다
# 빡치다
# 빵국
# 빵터지다
# 빵셔틀
# 뽀록
# 뿜다
# 뿜다
# 사스가
# 세크스
# 스까, 스까국
# 신컨
# 쉴드
# 썸
# 썸남
# 썸녀
# 사이다
# 성진국
# 썰
# 썰 풀다
# 수치플
# 스브스
# 시발비용
# 신박하다
# 신기(신성기사)
# 신박(신성바퀴벌레)
# 씹다
# 씹덕
# 오타쿠
# 오덕후
# 선비
# 솔까말
# 쌉~
# 씹~
# 아몰랑
# 안구 정화
# 안구 테러
# 안 생겨요
# -알못
# 앙 기모띠
# 얀데레
# 어장 관리
# 오나전
# 오덕후
# 오덕
# ㅗㅜㅑ
# 퍄
# 오크
# 엘프
# 올ㅋ
# 외계어
# 웅앵웅
# 웜퇘지
# 욜로
# 용자
# 이생망
# 인증
# 인정하는 부분
# 일베충
# 일진
# 잉여
# 오뱅알/ㅇㅂㅇ
# 왜구루냥
# 자강두천
# 잠수
# 작붕
# 저런하다
# 조무사
# 종결자
# 좆문가
# 주작
# 지름신
# 지르다
# 뽐뿌
# 진지충
# 짐승남, 짐승돌
# 초식남
# 짜지다
# 짱
# 쩐
# 찰지구나
# 창렬
# 총알
# ...

# %%
means = soup.select(
    '#mw-content-text > div > ul > li'
    )

# %%
for word in means:
    print(word.text)
# Out:
# -각: 무엇인가를 확신할 때 쓰는 접미사. ex)인정각,영정각
# 가드올: 「형용사」대한민국의 '이 앙 다물어라' 또는 '이 꽉 깨물어' 등에 해당되는 말로, '맞을 준비해라' 또는 '아파도 참아라'는 의미를 가지고 있다.
# 가즈아: 가즈아는 “가자”를 길게 발음한 것이며 과거 스포츠 도박 같은 것을 하는 사람들이 쓰던 말이다. 요즘에는 비트코인 시장에서 자주 쓰인다고 한다.
# 갓-: 「접사」god(神)을 어떤 대상의 이름 앞에 붙여 '그 대상이 신(神)적이다'는 뜻을 부여하여 칭송한다. 예) 갓메시, 갓한민국(대한민국), 갓수(돈 많은 백수)
# 개-: 정말, 완전 이란 뜻이다. 예) 개좋음, 개꿀, 개이득
# 검은머리 외국인: 핏줄만 한국인, 외국 국적을 가진 사람을 말한다.
# ...

# %%
import pandas as pd

# %%
A = []
B = []
for word in means:
    if 
    print(word.text)
    A.append(word.text.split(':')[0])
    B.append("".join(word.text.split(':')[1:]))
# Out:
# -각: 무엇인가를 확신할 때 쓰는 접미사. ex)인정각,영정각
# 가드올: 「형용사」대한민국의 '이 앙 다물어라' 또는 '이 꽉 깨물어' 등에 해당되는 말로, '맞을 준비해라' 또는 '아파도 참아라'는 의미를 가지고 있다.
# 가즈아: 가즈아는 “가자”를 길게 발음한 것이며 과거 스포츠 도박 같은 것을 하는 사람들이 쓰던 말이다. 요즘에는 비트코인 시장에서 자주 쓰인다고 한다.
# 갓-: 「접사」god(神)을 어떤 대상의 이름 앞에 붙여 '그 대상이 신(神)적이다'는 뜻을 부여하여 칭송한다. 예) 갓메시, 갓한민국(대한민국), 갓수(돈 많은 백수)
# 개-: 정말, 완전 이란 뜻이다. 예) 개좋음, 개꿀, 개이득
# 검은머리 외국인: 핏줄만 한국인, 외국 국적을 가진 사람을 말한다.
# ...

# %%
word_dic = {"Word":A,"Mean":B}

# %%
df = pd.DataFrame(word_dic, columns=["Word","Mean"])

# %%
df.isnull().sum()
# Out:
# Word    0
# Mean    0
# dtype: int64

# %%
df = df[:554]

# %%
df
# Out:
#                          Word  \
# 0                          -각
# 1                         가드올
# 2                         가즈아
# 3                          갓-
# 4                          개-
# 5                    검은머리 외국인
# 6    고고씽(Go Go 씽, 고고싱 혹은 ㄱㄱㅆ)
# 7                         고인물
# 8                     개인전(갠전)
# 9                     개인톡(갠톡)
# 10                        관심병
# 11                        귀요미
# 12                       귀차니즘
# 13                      그린라이트
# 14                        급식충
# 15                        기레기
# 16                        김여사
# 17                         -까
# 18                         꿀잼
# 19                        끝판왕
# 20                        낫닝겐
# 21                         낚시
# 22                        냥집사
# 23                        네가지
# 24                         노답
# 25                         노잼
# 26                        뇌피셜
# 27                        눈팅
# 28                        뉴비
# 29                        늅늅
# ...

# %%
df['Mean']=df['Mean'].apply(lambda x : x.replace(u'\xa0', ' '))
df['Word']=df['Word'].apply(lambda x : x.replace(u'\xa0', ' '))

# %%
df.to_csv('신조어.csv',encoding='utf-8')
